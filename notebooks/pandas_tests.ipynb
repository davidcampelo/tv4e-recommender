# %%
# read CSV using a relative path
import pandas as pd
import requests
URL='http://api_mysql.tv4e.pt/api/recommendations/users'
data= requests.get(URL)
df=pd.DataFrame(data.json())

# %%
df.head()
# Out:
#    city_id  user_age       user_coordinates user_gender  user_id  \
# 0        3        74  40.6311386,-8.6574267           M        1
# 1        3        85                    XXX           M        2
# 2        5        80  40.4796835,-8.4561561           M        3
# 3        5        65    40.629803,-8.608807           M        4
# 4        5        58  40.6023542,-8.5682549           M        6
#
#          user_name
# 0              Dev
# 1              XXX
# 2    David Campelo
# 3  Francisco Silva
# 4          Sir Ian

# %%
df.city_id.unique()
# Out:
# array([ 3,  5, 12,  2])

# %%
# read CSV using a relative path
import pandas as pd
import requests
URL='http://api_mysql.tv4e.pt/api/recommendations/ratings'
data= requests.get(URL)
df=pd.DataFrame(data.json())

# %%
df
# Out:
#     rating_date_creation  rating_value  user_id  video_id  video_watch_time  \
# 0    2018-01-11 12:01:31           0.0        1      4905                 1
# 1    2018-01-11 12:01:23           1.0        1      4931                 1
# 2    2018-01-11 12:00:12           0.0        1      4943                 3
# 3    2018-01-11 12:00:06           NaN        1      4980                 1
# 4    2018-01-11 12:00:02           NaN        1      4981                 1
# 5    2018-01-11 11:59:57           NaN        1      4987                 1
# 6    2018-01-11 11:59:40           NaN        1      4990                 1
# 7    2018-01-11 11:58:16           0.0        1      5000                 1
# 8    2018-01-11 11:56:04           1.0        1      5002                 1
# 9    2018-01-11 11:54:48           1.0        1      5004                 2
# 10   2018-01-11 11:54:42           NaN        1      5035                 1
# 11   2018-01-11 11:54:38           NaN        1      5154                 5
# 12   2018-01-10 15:10:35           0.0        1      5162               100
# 13   2018-01-10 10:38:25           NaN        1      5168               100
# 14   2018-01-10 10:30:44           NaN        1      5171               100
# 15   2018-01-10 17:33:05           0.0        1      5183                 2
# 16   2018-01-10 15:36:15           NaN        1      5186               100
# 17   2017-12-07 02:30:00           1.0        3      4448                87
# 18   2017-12-06 22:00:01          -1.0        3      4576               100
# 19   2017-12-07 02:00:00           1.0        3      4617                23
# 20   2017-12-06 23:00:04           NaN        3      4674               100
# 21   2017-12-06 23:30:01          -1.0        3      4699               100
# 22   2017-12-05 11:00:00           0.0        3      4700                 8
# 23   2017-12-06 22:30:01           NaN        3      4706                55
# 24   2017-12-02 05:00:00           NaN        3      4720                40
# 25   2017-12-02 03:30:00           NaN        3      4724               100
# 26   2017-12-01 23:00:00           1.0        3      4726               100
# 27   2017-12-01 23:30:00           NaN        3      4728               100
# 28   2017-12-05 14:30:01           1.0        3      4746               100
# 29   2017-12-05 14:00:00           1.0        3      4747                90
# ..                   ...           ...      ...       ...               ...
# 455  2017-12-12 09:00:01           0.0       23      4811                90
# 456  2017-12-14 16:00:01           0.0       23      4880               100
# 457  2017-12-13 19:30:00           0.0       24      4861               100
# 458  2017-12-16 10:30:00           NaN       24      4891               100
# 459  2017-12-18 21:30:01           NaN       24      4907               100
# 460  2017-12-18 18:22:16           0.0       24      4908               100
# 461  2017-12-18 21:00:01           0.0       24      4909               100
# 462  2017-12-18 20:00:01           0.0       24      4910               100
# 463  2017-12-18 19:30:01           NaN       24      4911               100
# 464  2017-12-18 19:00:01           NaN       24      4912               100
# 465  2017-12-18 18:30:01           NaN       24      4913               100
# 466  2017-12-18 20:30:01           0.0       24      4914               100
# 467  2017-12-19 05:30:00           NaN       24      4916               100
# 468  2017-12-19 22:00:01           NaN       24      4922               100
# 469  2017-12-20 18:33:11           NaN       24      4939                93
# 470  2017-12-20 18:40:40           0.0       24      4943               100
# 471  2017-12-21 16:30:00           NaN       24      4956                 1
# 472  2017-12-10 15:30:00           NaN       25      4710                 1
# 473  2017-12-10 15:00:00           1.0       25      4712               100
# 474  2017-12-06 08:30:00           0.0       25      4747               100
# 475  2017-12-05 10:00:00           0.0       25      4751               100
# 476  2017-12-05 09:30:00           NaN       25      4752                15
# 477  2017-12-12 17:00:00           NaN       25      4825               100
# 478  2017-12-12 07:00:00           1.0       25      4827                84
# 479  2017-12-12 17:30:00           NaN       25      4831                 2
# 480  2017-12-17 14:00:00           0.0       25      4893               100
# 481  2017-12-17 15:00:00           0.0       25      4905                 1
# 482  2017-12-17 14:30:01           NaN       25      4906               100
# 483  2017-12-18 17:30:00           NaN       25      4910               100
# 484  2017-12-18 17:00:00           0.0       25      4911               100
#
#     video_watched_type
# 0               forced
# 1               forced
# 2               forced
# 3               forced
# 4               forced
# 5               forced
# 6               forced
# 7               forced
# 8               forced
# 9               forced
# 10              forced
# 11              forced
# 12            injected
# 13            injected
# 14            injected
# 15              forced
# 16            injected
# 17            notified
# 18            notified
# 19            notified
# 20            notified
# 21            notified
# 22            notified
# 23            notified
# 24            notified
# 25            notified
# 26            notified
# 27            notified
# 28            notified
# 29            notified
# ..                 ...
# 455           notified
# 456           notified
# 457           injected
# 458           injected
# 459           injected
# 460             forced
# 461           injected
# 462           injected
# 463           injected
# 464           injected
# 465           injected
# 466           injected
# 467           injected
# 468           injected
# 469             forced
# 470             forced
# 471           notified
# 472           notified
# 473           notified
# 474           notified
# 475           notified
# 476           notified
# 477           notified
# 478           notified
# 479           notified
# 480           injected
# 481           injected
# 482           injected
# 483           injected
# 484           injected
#
# [485 rows x 6 columns]

# %%
# read CSV using a relative path
import pandas as pd
import requests
URL='http://api_mysql.tv4e.pt/api/recommendations/ratings'
data= requests.get(URL)
df=pd.DataFrame(data.json())

# XXX use a function to calculate implicit rating considering the video lead time
df['rating_implicit'] = (df['video_watch_time']/100) * 0.3
df['rating_explicit'] = (df['rating_value'])         * 0.7
# If the explicit rating was negative, the implicit will be negative
df['rating_implicit'][df.rating_explicit < 0] = df['rating_implicit'] * -1
# create a new column to put implicit or explicit rating rating_value
df['overall_rating_value'] = df['rating_implicit'] + df['rating_explicit']

# implicit rating is the watched time / explicit rating is the like-0-dislike
df['rating_implicit'] = df['video_watch_time']/100
df['rating_explicit'] = df['rating_value']
df['overall_rating_value']=df['overall_rating_value'].fillna(0)

df.loc[(df['overall_rating_value'] == 0) & (df['video_watch_time'] > 25),'overall_rating_value'] = (df['video_watch_time']/100) * 0.5
#df = df[(df.video_watched_type != 'forced')]
import datetime
NOW = datetime.datetime.now()
df['rating_date_diff'] = NOW - pd.to_datetime(df['rating_date_creation'])
df = df[(df.rating_date_diff.dt.days < 14)]
#df = df[(df.overall_rating_value > 0)]
df.shape
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# (143, 10)

# %%
import numpy as np
for index, row in df.iterrows():
    print("explicit = {}".format(row.rating_explicit))
    if row.rating_explicit:
        print("index = {} row = {}".format(index,row))
# Out:
# explicit = 0.0
# explicit = nan
# index = 13 row = rating_date_creation    2018-01-10 10:38:25
# rating_value                            NaN
# user_id                                   1
# video_id                               5168
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 13, dtype: object
# explicit = nan
# index = 14 row = rating_date_creation    2018-01-10 10:30:44
# rating_value                            NaN
# user_id                                   1
# video_id                               5171
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 14, dtype: object
# explicit = nan
# index = 16 row = rating_date_creation    2018-01-10 15:36:15
# rating_value                            NaN
# user_id                                   1
# video_id                               5186
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 16, dtype: object
# explicit = 1.0
# index = 17 row = rating_date_creation    2017-12-07 02:30:00
# rating_value                              1
# user_id                                   3
# video_id                               4448
# video_watch_time                         87
# video_watched_type                 notified
# rating_implicit                        0.87
# rating_explicit                           1
# overall_rating_value                  0.961
# Name: 17, dtype: object
# explicit = -1.0
# index = 18 row = rating_date_creation    2017-12-06 22:00:01
# rating_value                             -1
# user_id                                   3
# video_id                               4576
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                          -1
# overall_rating_value                     -1
# Name: 18, dtype: object
# explicit = 1.0
# index = 19 row = rating_date_creation    2017-12-07 02:00:00
# rating_value                              1
# user_id                                   3
# video_id                               4617
# video_watch_time                         23
# video_watched_type                 notified
# rating_implicit                        0.23
# rating_explicit                           1
# overall_rating_value                  0.769
# Name: 19, dtype: object
# explicit = nan
# index = 20 row = rating_date_creation    2017-12-06 23:00:04
# rating_value                            NaN
# user_id                                   3
# video_id                               4674
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 20, dtype: object
# explicit = -1.0
# index = 21 row = rating_date_creation    2017-12-06 23:30:01
# rating_value                             -1
# user_id                                   3
# video_id                               4699
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                          -1
# overall_rating_value                     -1
# Name: 21, dtype: object
# explicit = 0.0
# explicit = nan
# index = 23 row = rating_date_creation    2017-12-06 22:30:01
# rating_value                            NaN
# user_id                                   3
# video_id                               4706
# video_watch_time                         55
# video_watched_type                 notified
# rating_implicit                        0.55
# rating_explicit                         NaN
# overall_rating_value                  0.275
# Name: 23, dtype: object
# explicit = nan
# index = 24 row = rating_date_creation    2017-12-02 05:00:00
# rating_value                            NaN
# user_id                                   3
# video_id                               4720
# video_watch_time                         40
# video_watched_type                 notified
# rating_implicit                         0.4
# rating_explicit                         NaN
# overall_rating_value                    0.2
# Name: 24, dtype: object
# explicit = nan
# index = 25 row = rating_date_creation    2017-12-02 03:30:00
# rating_value                            NaN
# user_id                                   3
# video_id                               4724
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 25, dtype: object
# explicit = 1.0
# index = 26 row = rating_date_creation    2017-12-01 23:00:00
# rating_value                              1
# user_id                                   3
# video_id                               4726
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 26, dtype: object
# explicit = nan
# index = 27 row = rating_date_creation    2017-12-01 23:30:00
# rating_value                            NaN
# user_id                                   3
# video_id                               4728
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 27, dtype: object
# explicit = 1.0
# index = 28 row = rating_date_creation    2017-12-05 14:30:01
# rating_value                              1
# user_id                                   3
# video_id                               4746
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 28, dtype: object
# explicit = 1.0
# index = 29 row = rating_date_creation    2017-12-05 14:00:00
# rating_value                              1
# user_id                                   3
# video_id                               4747
# video_watch_time                         90
# video_watched_type                 notified
# rating_implicit                         0.9
# rating_explicit                           1
# overall_rating_value                   0.97
# Name: 29, dtype: object
# explicit = nan
# index = 30 row = rating_date_creation    2017-12-05 12:00:00
# rating_value                            NaN
# user_id                                   3
# video_id                               4749
# video_watch_time                          9
# video_watched_type                 notified
# rating_implicit                        0.09
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 30, dtype: object
# explicit = nan
# index = 31 row = rating_date_creation    2017-12-07 05:00:00
# rating_value                            NaN
# user_id                                   3
# video_id                               4763
# video_watch_time                         33
# video_watched_type                 notified
# rating_implicit                        0.33
# rating_explicit                         NaN
# overall_rating_value                  0.165
# Name: 31, dtype: object
# explicit = 0.0
# explicit = -1.0
# index = 33 row = rating_date_creation    2017-12-07 03:00:00
# rating_value                             -1
# user_id                                   3
# video_id                               4767
# video_watch_time                          6
# video_watched_type                 notified
# rating_implicit                        0.06
# rating_explicit                          -1
# overall_rating_value                 -0.718
# Name: 33, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 47 row = rating_date_creation    2018-01-10 16:35:19
# rating_value                            NaN
# user_id                                   4
# video_id                               5068
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 47, dtype: object
# explicit = 0.0
# explicit = -1.0
# index = 50 row = rating_date_creation    2018-01-08 17:09:23
# rating_value                             -1
# user_id                                   4
# video_id                               5160
# video_watch_time                         95
# video_watched_type                 notified
# rating_implicit                        0.95
# rating_explicit                          -1
# overall_rating_value                 -0.985
# Name: 50, dtype: object
# explicit = 0.0
# explicit = nan
# index = 52 row = rating_date_creation    2018-01-10 17:03:35
# rating_value                            NaN
# user_id                                   4
# video_id                               5186
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 52, dtype: object
# explicit = 0.0
# explicit = nan
# index = 54 row = rating_date_creation    2018-01-10 16:58:35
# rating_value                            NaN
# user_id                                   4
# video_id                               5188
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 54, dtype: object
# explicit = nan
# index = 55 row = rating_date_creation    2018-01-10 16:53:35
# rating_value                            NaN
# user_id                                   4
# video_id                               5189
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 55, dtype: object
# explicit = 0.0
# explicit = nan
# index = 57 row = rating_date_creation    2018-01-10 17:13:36
# rating_value                            NaN
# user_id                                   4
# video_id                               5194
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 57, dtype: object
# explicit = 1.0
# index = 59 row = rating_date_creation    2017-12-04 11:00:00
# rating_value                              1
# user_id                                   6
# video_id                               4737
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 59, dtype: object
# explicit = 0.0
# explicit = -1.0
# index = 61 row = rating_date_creation    2017-12-09 00:00:00
# rating_value                             -1
# user_id                                   7
# video_id                               4672
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                          -1
# overall_rating_value                     -1
# Name: 61, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 63 row = rating_date_creation    2017-12-03 21:30:00
# rating_value                              1
# user_id                                   7
# video_id                               4721
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 63, dtype: object
# explicit = nan
# index = 64 row = rating_date_creation    2017-12-15 20:00:01
# rating_value                            NaN
# user_id                                   7
# video_id                               4741
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 64, dtype: object
# explicit = 0.0
# explicit = nan
# index = 66 row = rating_date_creation    2017-12-15 21:30:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4753
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 66, dtype: object
# explicit = 1.0
# index = 67 row = rating_date_creation    2017-12-10 22:30:01
# rating_value                              1
# user_id                                   7
# video_id                               4774
# video_watch_time                         69
# video_watched_type                 notified
# rating_implicit                        0.69
# rating_explicit                           1
# overall_rating_value                  0.907
# Name: 67, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 69 row = rating_date_creation    2017-12-11 23:00:00
# rating_value                              1
# user_id                                   7
# video_id                               4809
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 69, dtype: object
# explicit = nan
# index = 70 row = rating_date_creation    2017-12-15 14:00:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4820
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 70, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 74 row = rating_date_creation    2017-12-15 13:00:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4890
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 74, dtype: object
# explicit = nan
# index = 75 row = rating_date_creation    2017-12-15 13:30:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4893
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 75, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 78 row = rating_date_creation    2017-12-16 14:00:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4898
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 78, dtype: object
# explicit = nan
# index = 79 row = rating_date_creation    2017-12-17 23:30:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4905
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 79, dtype: object
# explicit = nan
# index = 80 row = rating_date_creation    2017-12-17 23:00:00
# rating_value                            NaN
# user_id                                   7
# video_id                               4906
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 80, dtype: object
# explicit = 1.0
# index = 81 row = rating_date_creation    2017-12-06 13:30:01
# rating_value                              1
# user_id                                   8
# video_id                               4459
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 81, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 83 row = rating_date_creation    2017-12-03 16:30:00
# rating_value                              1
# user_id                                   8
# video_id                               4549
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 83, dtype: object
# explicit = nan
# index = 84 row = rating_date_creation    2017-12-04 12:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4554
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 84, dtype: object
# explicit = nan
# index = 85 row = rating_date_creation    2017-12-16 15:00:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4563
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 85, dtype: object
# explicit = nan
# index = 86 row = rating_date_creation    2017-12-02 16:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4574
# video_watch_time                         29
# video_watched_type                 notified
# rating_implicit                        0.29
# rating_explicit                         NaN
# overall_rating_value                  0.145
# Name: 86, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 88 row = rating_date_creation    2017-12-06 14:00:01
# rating_value                              1
# user_id                                   8
# video_id                               4704
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 88, dtype: object
# explicit = 1.0
# index = 89 row = rating_date_creation    2017-12-02 16:00:00
# rating_value                              1
# user_id                                   8
# video_id                               4714
# video_watch_time                         22
# video_watched_type                 notified
# rating_implicit                        0.22
# rating_explicit                           1
# overall_rating_value                  0.766
# Name: 89, dtype: object
# explicit = 1.0
# index = 90 row = rating_date_creation    2017-12-05 14:00:01
# rating_value                              1
# user_id                                   8
# video_id                               4751
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 90, dtype: object
# explicit = nan
# index = 91 row = rating_date_creation    2017-12-18 15:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4759
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 91, dtype: object
# explicit = nan
# index = 92 row = rating_date_creation    2017-12-07 14:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4768
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 92, dtype: object
# explicit = nan
# index = 93 row = rating_date_creation    2017-12-07 13:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4770
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 93, dtype: object
# explicit = 0.0
# explicit = nan
# index = 95 row = rating_date_creation    2017-12-15 22:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4810
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 95, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 98 row = rating_date_creation    2017-12-15 20:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4820
# video_watch_time                         21
# video_watched_type                 injected
# rating_implicit                        0.21
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 98, dtype: object
# explicit = nan
# index = 99 row = rating_date_creation    2017-12-15 14:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4824
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 99, dtype: object
# explicit = nan
# index = 100 row = rating_date_creation    2017-12-15 16:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4825
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 100, dtype: object
# explicit = nan
# index = 101 row = rating_date_creation    2017-12-15 12:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4826
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 101, dtype: object
# explicit = nan
# index = 102 row = rating_date_creation    2017-12-12 20:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4851
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 102, dtype: object
# explicit = nan
# index = 103 row = rating_date_creation    2017-12-14 14:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4853
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 103, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 109 row = rating_date_creation    2017-12-14 22:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4880
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 109, dtype: object
# explicit = 0.0
# explicit = nan
# index = 111 row = rating_date_creation    2017-12-14 21:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4882
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 111, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 115 row = rating_date_creation    2017-12-15 13:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4893
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 115, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 119 row = rating_date_creation    2017-12-18 13:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4910
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 119, dtype: object
# explicit = nan
# index = 120 row = rating_date_creation    2017-12-18 15:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4912
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 120, dtype: object
# explicit = nan
# index = 121 row = rating_date_creation    2017-12-19 13:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4917
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 121, dtype: object
# explicit = nan
# index = 122 row = rating_date_creation    2017-12-19 12:30:01
# rating_value                            NaN
# user_id                                   8
# video_id                               4919
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 122, dtype: object
# explicit = 0.0
# explicit = nan
# index = 124 row = rating_date_creation    2017-12-19 21:00:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4926
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 124, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 127 row = rating_date_creation    2017-12-27 12:34:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4958
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 127, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 130 row = rating_date_creation    2017-12-22 15:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4977
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 130, dtype: object
# explicit = nan
# index = 131 row = rating_date_creation    2017-12-23 13:30:00
# rating_value                            NaN
# user_id                                   8
# video_id                               4978
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 131, dtype: object
# explicit = nan
# index = 132 row = rating_date_creation    2017-12-23 13:41:28
# rating_value                            NaN
# user_id                                   8
# video_id                               4981
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 132, dtype: object
# explicit = nan
# index = 133 row = rating_date_creation    2017-12-27 12:20:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5000
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 133, dtype: object
# explicit = nan
# index = 134 row = rating_date_creation    2017-12-27 16:16:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5004
# video_watch_time                         17
# video_watched_type                 injected
# rating_implicit                        0.17
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 134, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 137 row = rating_date_creation    2017-12-28 12:15:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5030
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 137, dtype: object
# explicit = nan
# index = 138 row = rating_date_creation    2017-12-29 12:57:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5031
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 138, dtype: object
# explicit = nan
# index = 139 row = rating_date_creation    2018-01-02 12:13:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5076
# video_watch_time                         14
# video_watched_type                 injected
# rating_implicit                        0.14
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 139, dtype: object
# explicit = 0.0
# explicit = nan
# index = 141 row = rating_date_creation    2018-01-03 12:08:00
# rating_value                            NaN
# user_id                                   8
# video_id                               5081
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 141, dtype: object
# explicit = nan
# index = 142 row = rating_date_creation    2018-01-11 01:58:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5087
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 142, dtype: object
# explicit = 0.0
# explicit = nan
# index = 144 row = rating_date_creation    2018-01-11 01:48:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5089
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 144, dtype: object
# explicit = nan
# index = 145 row = rating_date_creation    2018-01-11 01:38:02
# rating_value                            NaN
# user_id                                   8
# video_id                               5090
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 145, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 148 row = rating_date_creation    2018-01-11 01:23:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5094
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 148, dtype: object
# explicit = nan
# index = 149 row = rating_date_creation    2018-01-11 01:18:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5095
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 149, dtype: object
# explicit = nan
# index = 150 row = rating_date_creation    2018-01-11 01:13:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5096
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 150, dtype: object
# explicit = nan
# index = 151 row = rating_date_creation    2018-01-11 01:08:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5100
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 151, dtype: object
# explicit = 0.0
# explicit = nan
# index = 153 row = rating_date_creation    2018-01-11 00:58:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5112
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 153, dtype: object
# explicit = nan
# index = 154 row = rating_date_creation    2018-01-11 00:53:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5121
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 154, dtype: object
# explicit = nan
# index = 155 row = rating_date_creation    2018-01-11 00:43:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5122
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 155, dtype: object
# explicit = nan
# index = 156 row = rating_date_creation    2018-01-11 00:38:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5123
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 156, dtype: object
# explicit = 0.0
# explicit = nan
# index = 158 row = rating_date_creation    2018-01-11 00:28:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5126
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 158, dtype: object
# explicit = nan
# index = 159 row = rating_date_creation    2018-01-11 00:23:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5127
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 159, dtype: object
# explicit = nan
# index = 160 row = rating_date_creation    2018-01-11 00:18:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5128
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 160, dtype: object
# explicit = 0.0
# explicit = nan
# index = 162 row = rating_date_creation    2018-01-11 00:08:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5138
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 162, dtype: object
# explicit = nan
# index = 163 row = rating_date_creation    2018-01-10 23:58:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5139
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 163, dtype: object
# explicit = nan
# index = 164 row = rating_date_creation    2018-01-10 23:53:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5142
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 164, dtype: object
# explicit = nan
# index = 165 row = rating_date_creation    2018-01-10 23:43:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5144
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 165, dtype: object
# explicit = nan
# index = 166 row = rating_date_creation    2018-01-10 23:38:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5149
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 166, dtype: object
# explicit = 0.0
# explicit = nan
# index = 168 row = rating_date_creation    2018-01-10 23:23:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5153
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 168, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 171 row = rating_date_creation    2018-01-10 23:08:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5156
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 171, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 174 row = rating_date_creation    2018-01-10 21:13:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5160
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 174, dtype: object
# explicit = 0.0
# explicit = nan
# index = 176 row = rating_date_creation    2018-01-10 22:53:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5162
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 176, dtype: object
# explicit = 0.0
# explicit = nan
# index = 178 row = rating_date_creation    2018-01-10 22:43:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5168
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 178, dtype: object
# explicit = nan
# index = 179 row = rating_date_creation    2018-01-10 21:08:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5171
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 179, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 182 row = rating_date_creation    2018-01-10 22:23:05
# rating_value                            NaN
# user_id                                   8
# video_id                               5174
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 182, dtype: object
# explicit = nan
# index = 183 row = rating_date_creation    2018-01-10 22:18:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5177
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 183, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 186 row = rating_date_creation    2018-01-10 21:58:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5184
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 186, dtype: object
# explicit = nan
# index = 187 row = rating_date_creation    2018-01-10 21:53:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5185
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 187, dtype: object
# explicit = 0.0
# explicit = nan
# index = 189 row = rating_date_creation    2018-01-10 21:43:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5190
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 189, dtype: object
# explicit = 0.0
# explicit = nan
# index = 191 row = rating_date_creation    2018-01-10 21:28:01
# rating_value                            NaN
# user_id                                   8
# video_id                               5192
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# ...
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 423, dtype: object
# explicit = 0.0
# explicit = nan
# index = 425 row = rating_date_creation    2017-12-20 21:30:00
# rating_value                            NaN
# user_id                                  18
# video_id                               4945
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 425, dtype: object
# explicit = nan
# index = 426 row = rating_date_creation    2017-12-20 21:00:00
# rating_value                            NaN
# user_id                                  18
# video_id                               4946
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 426, dtype: object
# explicit = nan
# index = 427 row = rating_date_creation    2017-12-21 08:30:00
# rating_value                            NaN
# user_id                                  18
# video_id                               4950
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 427, dtype: object
# explicit = nan
# index = 428 row = rating_date_creation    2017-12-21 10:30:00
# rating_value                            NaN
# user_id                                  18
# video_id                               4951
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 428, dtype: object
# explicit = nan
# index = 429 row = rating_date_creation    2017-12-13 12:00:00
# rating_value                            NaN
# user_id                                  20
# video_id                               4615
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 429, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 431 row = rating_date_creation    2017-12-05 20:30:01
# rating_value                              1
# user_id                                  20
# video_id                               4672
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 431, dtype: object
# explicit = 0.0
# explicit = -1.0
# index = 433 row = rating_date_creation    2017-12-05 23:00:01
# rating_value                             -1
# user_id                                  20
# video_id                               4752
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                          -1
# overall_rating_value                     -1
# Name: 433, dtype: object
# explicit = nan
# index = 434 row = rating_date_creation    2017-12-05 22:30:01
# rating_value                            NaN
# user_id                                  20
# video_id                               4753
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 434, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 1.0
# index = 437 row = rating_date_creation    2017-12-06 21:30:00
# rating_value                              1
# user_id                                  20
# video_id                               4765
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 437, dtype: object
# explicit = nan
# index = 438 row = rating_date_creation    2017-12-13 11:00:01
# rating_value                            NaN
# user_id                                  20
# video_id                               4770
# video_watch_time                         31
# video_watched_type                 notified
# rating_implicit                        0.31
# rating_explicit                         NaN
# overall_rating_value                  0.155
# Name: 438, dtype: object
# explicit = 0.0
# explicit = 1.0
# index = 441 row = rating_date_creation    2017-12-10 17:30:01
# rating_value                              1
# user_id                                  20
# video_id                               4791
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 441, dtype: object
# explicit = 0.0
# explicit = nan
# index = 443 row = rating_date_creation    2017-12-15 21:30:01
# rating_value                            NaN
# user_id                                  20
# video_id                               4827
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 443, dtype: object
# explicit = nan
# index = 444 row = rating_date_creation    2017-12-15 21:00:01
# rating_value                            NaN
# user_id                                  20
# video_id                               4893
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 444, dtype: object
# explicit = 1.0
# index = 445 row = rating_date_creation    2017-12-15 23:00:01
# rating_value                              1
# user_id                                  20
# video_id                               4895
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 445, dtype: object
# explicit = -1.0
# index = 446 row = rating_date_creation    2018-01-08 17:08:36
# rating_value                             -1
# user_id                                  20
# video_id                               5089
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                          -1
# overall_rating_value                     -1
# Name: 446, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 450 row = rating_date_creation    2018-01-08 17:13:36
# rating_value                            NaN
# user_id                                  20
# video_id                               5162
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 450, dtype: object
# explicit = nan
# index = 451 row = rating_date_creation    2017-12-06 17:30:00
# rating_value                            NaN
# user_id                                  23
# video_id                               4711
# video_watch_time                          9
# video_watched_type                 notified
# rating_implicit                        0.09
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 451, dtype: object
# explicit = nan
# index = 452 row = rating_date_creation    2017-12-06 16:00:00
# rating_value                            NaN
# user_id                                  23
# video_id                               4760
# video_watch_time                         37
# video_watched_type                 notified
# rating_implicit                        0.37
# rating_explicit                         NaN
# overall_rating_value                  0.185
# Name: 452, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 458 row = rating_date_creation    2017-12-16 10:30:00
# rating_value                            NaN
# user_id                                  24
# video_id                               4891
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 458, dtype: object
# explicit = nan
# index = 459 row = rating_date_creation    2017-12-18 21:30:01
# rating_value                            NaN
# user_id                                  24
# video_id                               4907
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 459, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 463 row = rating_date_creation    2017-12-18 19:30:01
# rating_value                            NaN
# user_id                                  24
# video_id                               4911
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 463, dtype: object
# explicit = nan
# index = 464 row = rating_date_creation    2017-12-18 19:00:01
# rating_value                            NaN
# user_id                                  24
# video_id                               4912
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 464, dtype: object
# explicit = nan
# index = 465 row = rating_date_creation    2017-12-18 18:30:01
# rating_value                            NaN
# user_id                                  24
# video_id                               4913
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 465, dtype: object
# explicit = 0.0
# explicit = nan
# index = 467 row = rating_date_creation    2017-12-19 05:30:00
# rating_value                            NaN
# user_id                                  24
# video_id                               4916
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 467, dtype: object
# explicit = nan
# index = 468 row = rating_date_creation    2017-12-19 22:00:01
# rating_value                            NaN
# user_id                                  24
# video_id                               4922
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 468, dtype: object
# explicit = nan
# index = 471 row = rating_date_creation    2017-12-21 16:30:00
# rating_value                            NaN
# user_id                                  24
# video_id                               4956
# video_watch_time                          1
# video_watched_type                 notified
# rating_implicit                        0.01
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 471, dtype: object
# explicit = nan
# index = 472 row = rating_date_creation    2017-12-10 15:30:00
# rating_value                            NaN
# user_id                                  25
# video_id                               4710
# video_watch_time                          1
# video_watched_type                 notified
# rating_implicit                        0.01
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 472, dtype: object
# explicit = 1.0
# index = 473 row = rating_date_creation    2017-12-10 15:00:00
# rating_value                              1
# user_id                                  25
# video_id                               4712
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                           1
# overall_rating_value                      1
# Name: 473, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 476 row = rating_date_creation    2017-12-05 09:30:00
# rating_value                            NaN
# user_id                                  25
# video_id                               4752
# video_watch_time                         15
# video_watched_type                 notified
# rating_implicit                        0.15
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 476, dtype: object
# explicit = nan
# index = 477 row = rating_date_creation    2017-12-12 17:00:00
# rating_value                            NaN
# user_id                                  25
# video_id                               4825
# video_watch_time                        100
# video_watched_type                 notified
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 477, dtype: object
# explicit = 1.0
# index = 478 row = rating_date_creation    2017-12-12 07:00:00
# rating_value                              1
# user_id                                  25
# video_id                               4827
# video_watch_time                         84
# video_watched_type                 notified
# rating_implicit                        0.84
# rating_explicit                           1
# overall_rating_value                  0.952
# Name: 478, dtype: object
# explicit = nan
# index = 479 row = rating_date_creation    2017-12-12 17:30:00
# rating_value                            NaN
# user_id                                  25
# video_id                               4831
# video_watch_time                          2
# video_watched_type                 notified
# rating_implicit                        0.02
# rating_explicit                         NaN
# overall_rating_value                      0
# Name: 479, dtype: object
# explicit = 0.0
# explicit = 0.0
# explicit = nan
# index = 482 row = rating_date_creation    2017-12-17 14:30:01
# rating_value                            NaN
# user_id                                  25
# video_id                               4906
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 482, dtype: object
# explicit = nan
# index = 483 row = rating_date_creation    2017-12-18 17:30:00
# rating_value                            NaN
# user_id                                  25
# video_id                               4910
# video_watch_time                        100
# video_watched_type                 injected
# rating_implicit                           1
# rating_explicit                         NaN
# overall_rating_value                    0.5
# Name: 483, dtype: object
# explicit = 0.0

# %%
# read CSV using a relative path
import pandas as pd
import requests
URL='http://api_mysql.tv4e.pt/api/recommendations/videos'
data= requests.get(URL)
df=pd.DataFrame(data.json())

# %%
df[df['video_location'] == '3'].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5169)()
#
# KeyError: 'video_location'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-331485a30392> in <module>()
# ----> 1 df[df['video_location'] == '3'].shape
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5169)()
#
# KeyError: 'video_location'

# %%
df.video_location.unique()

# %%
from dateutil import parser
pd.to_datetime(df.video_date_creation)
df=df.sort_values(['video_date_creation'])

datett = df[(df['video_id'] == 4402)].video_date_creation[0]
parser.parse(datett)

# n_recommendations=5
# filtered_recommendations = {video_id: "" for video_id in df[:-n_recommendations-1:-1].video_id}
# filtered_recommendations

# %%
recs = [(video.video_id, video.video_date_creation, "")
                                        for index,video in df[:-5:-1].iterrows()]
recs

# %%
import datetime
now = datetime.datetime.now()
for index,row in df[:-5:-1].iterrows():
    date = parser.parse(row.video_date_creation)
    diff = now-date
    print(diff)

# %%
import dateutil
# read CSV using a relative path
import pandas as pd
import requests
URL='http://api_mysql.tv4e.pt/api/recommendations/videos'
data= requests.get(URL)
df=pd.DataFrame(data.json())
df = df.transpose()
for index, row in df.iterrows():
    print("\n")
    print(row.video_id)
    print(row.video_title)
    print(row.video_desc)
    print(dateutil.parser.parse(row.video_date_creation))
    print(row.video_location)
    print(row.video_asgie_id)
    print(row.video_asgie_title_pt)
